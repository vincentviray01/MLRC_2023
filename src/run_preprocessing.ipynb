# %%
import papermill as pm
import mlflow
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Default Parameters
run_id = None
train_data_path = "/home/vincent/projects/MLRC_2023/data/ImageNet/ILSVRC/Data/CLS-LOC/train/n07753275/"
test_data_path = "/home/vincent/projects/MLRC_2023/data/ImageNet/ILSVRC/Data/CLS-LOC/train/n07753113/"

train_data_save_path = "/home/vincent/projects/MLRC_2023/data/ImageNet/preprocessed/ImageNet/train/"
test_data_save_path = "/home/vincent/projects/MLRC_2023/data/ImageNet/preprocessed/ImageNet/test/"

train_data = []
test_data = []

# %%
# if using pretrained model
from torchvision.models import ResNet50_Weights

resnet50_weights = ResNet50_Weights.DEFAULT

# img_transformed = preprocess(img)
preprocess = resnet50_weights.transforms()

# %%
# read train_data
for file in os.listdir(train_data_path):
    image = plt.imread(train_data_path + file)
    # if image only has 2 dimensions, add a 3rd dimension
    if len(image.shape) == 2:
        image = np.stack((image,) * 3, axis=-1)
    preprocessed_image = preprocess(Image.fromarray(image))
    train_data.append(preprocessed_image)
    
for file in os.listdir(test_data_path):
    image = plt.imread(test_data_path + file)
    print
    # if image only has 2 dimensions, add a 3rd dimension
    if len(image.shape) == 2:
        image = np.stack((image,) * 3, axis=-1)
    preprocessed_image = preprocess(Image.fromarray(image))
    test_data.append(preprocessed_image)

# %%
from torch.utils.data import Dataset
import torch

# %%
plt.imshow(torch.swapaxes(test_data[0], 0, 2).numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from utils import md5_dir

#train_directory = "data/ImageNet/train"
#test_directory = "data/ImageNet/test/"

train_data_path = "/home/vincent/projects/MLRC_2023/data/ImageNet/ILSVRC/Data/CLS-LOC/train/n07753275/"
test_data_path = "/home/vincent/projects/MLRC_2023/data/ImageNet/ILSVRC/Data/CLS-LOC/train/n07753113/"

#train_set_hash = md5_dir(train_directory)
test_set_hash = md5_dir(test_data_path)

# %%
with mlflow.start_run(run_id=run_id):
    mlflow.log_param("random_param", 3)
    environment_path = "environment.txt"
    mlflow.log_artifact("environment", environment_path)
    mlflow.log_param("test_set_hash", test_set_hash)
    mlflow.log_param("train_set_hash", train_set_hash)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 4
#       2 mlflow.log_param("random_param", 3)
#       3 environment_path = "environment.txt"
# ----> 4 mlflow.log_artifact("environment", environment_path)
#
# File ~/anaconda3/envs/mlrc_2023/lib/python3.11/site-packages/mlflow/tracking/fluent.py:266, in log_artifact(local_path, artifact_path)
#     259 """
#     260 Log a local file as an artifact of the currently active run.
#     261
#     262 :param local_path: Path to the file to write.
#     263 :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     264 """
#     265 run_id = _get_or_start_run().info.run_id
# --> 266 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/anaconda3/envs/mlrc_2023/lib/python3.11/site-packages/mlflow/tracking/client.py:243, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#     241 run = self.get_run(run_id)
#     242 artifact_repo = get_artifact_repository(run.info.artifact_uri)
# --> 243 artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~/anaconda3/envs/mlrc_2023/lib/python3.11/site-packages/mlflow/store/local_artifact_repo.py:32, in LocalArtifactRepository.log_artifact(self, local_file, artifact_path)
#      30 if not os.path.exists(artifact_dir):
#      31     mkdir(artifact_dir)
# ---> 32 shutil.copy(local_file, artifact_dir)
#
# File ~/anaconda3/envs/mlrc_2023/lib/python3.11/shutil.py:419, in copy(src, dst, follow_symlinks)
#     417 if os.path.isdir(dst):
#     418     dst = os.path.join(dst, os.path.basename(src))
# --> 419 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     420 copymode(src, dst, follow_symlinks=follow_symlinks)
#     421 return dst
#
# File ~/anaconda3/envs/mlrc_2023/lib/python3.11/shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254     os.symlink(os.readlink(src), dst)
#     255 else:
# --> 256     with open(src, 'rb') as fsrc:
#     257         try:
#     258             with open(dst, 'wb') as fdst:
#     259                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'environment'
